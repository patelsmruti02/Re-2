# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv("C:\\Users\\DEll\\Downloads\\CARS.csv")

cars
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
cars.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
cars.tail(50)
# Out:
#           Make   Model  Year                Engine Fuel Type  Engine HP  \
# 11864      GMC   Yukon  2015        flex-fuel (unleaded/E85)      355.0
# 11865      GMC   Yukon  2015        flex-fuel (unleaded/E85)      355.0
# 11866      GMC   Yukon  2015        flex-fuel (unleaded/E85)      355.0
# 11867      GMC   Yukon  2015  premium unleaded (recommended)      420.0
# 11868      GMC   Yukon  2015  premium unleaded (recommended)      420.0
# 11869      GMC   Yukon  2016  premium unleaded (recommended)      420.0
# 11870      GMC   Yukon  2016        flex-fuel (unleaded/E85)      355.0
# 11871      GMC   Yukon  2016  premium unleaded (recommended)      420.0
# 11872      GMC   Yukon  2016        flex-fuel (unleaded/E85)      355.0
# 11873      GMC   Yukon  2016        flex-fuel (unleaded/E85)      355.0
# 11874      GMC   Yukon  2016        flex-fuel (unleaded/E85)      355.0
# 11875      GMC   Yukon  2017  premium unleaded (recommended)      420.0
# ...

# %%
cars.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
print(cars.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
s_h = cars.dropna(how = 'any')

s_h
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders  Number of Doors  \
# ...

# %%
cars['MSRP'].is_unique
# Out:
# False

# %%
cars['Model'].dtype
# Out:
# dtype('O')

# %%
cars['Market Category'].isnull().sum()/len(cars)
# Out:
# 0.31408427060600974

# %%
print(cars.loc[[0,98,372,577,890,11748]])
# Out:
#          Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0         BMW  1 Series M  2011     premium unleaded (required)      335.0
# 98     Nissan       240SX  1997                regular unleaded      155.0
# 372     Mazda           3  2015                regular unleaded      155.0
# 577      FIAT        500L  2016  premium unleaded (recommended)      160.0
# 890      Saab         900  1996                regular unleaded      150.0
# 11748  Nissan      Xterra  2013                regular unleaded      261.0
#
#        Engine Cylinders  Number of Doors  \
# 0                   6.0              2.0
# 98                  4.0              2.0
# 372                 4.0              4.0
# 577                 4.0              4.0
# 890                 4.0              4.0
# 11748               6.0              4.0
#
#                              Market Category Vehicle Size  highway MPG  \
# 0      Factory Tuner,Luxury,High-Performance      Compact           26
# ...

# %%
print(pd.options.display.max_rows)
# Out:
# 60

# %%
pd.options.display.max_rows = 11199

# %%
print(pd.options.display.max_rows)
# Out:
# 11199

# %%
print(pd.__version__)
# Out:
# 1.4.2

# %% [markdown]
# ## cleaning data

# %%
print(cars.duplicated().to_string())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14        True
# 15       False
# 16       False
# 17       False
# 18        True
# 19       False
# 20        True
# 21       False
# 22       False
# 23       False
# 24        True
# 25        True
# 26       False
# 27       False
# 28       False
# 29       False
# 30        True
# 31        True
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47       False
# 48       False
# 49       False
# 50       False
# 51       False
# 52       False
# 53       False
# 54       False
# 55       False
# 56       False
# 57       False
# ...

# %%
cars.drop_duplicates(inplace = True)
print(cars.duplicated().to_string())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 15       False
# 16       False
# 17       False
# 19       False
# 21       False
# 22       False
# 23       False
# 26       False
# 27       False
# 28       False
# 29       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47       False
# 48       False
# 49       False
# 50       False
# 51       False
# 52       False
# 53       False
# 54       False
# 55       False
# 56       False
# 57       False
# 58       False
# 59       False
# 60       False
# 61       False
# 63       False
# 64       False
# 65       False
# ...

# %%
drop_column = ['Transmission Type','Driven_Wheels','Vehicle Style']

cars.drop(columns = drop_column,inplace = True)

cars
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders  Number of Doors  \
# ...

# %%
print(cars.describe())
# Out:
#                Year     Engine HP  Engine Cylinders  Number of Doors  \
# count  11111.000000  11042.000000      11081.000000     11105.000000
# mean    2010.822608    254.037040          5.669434         3.455471
# std        7.122102    110.084349          1.799271         0.872254
# min     1990.000000     55.000000          0.000000         2.000000
# 25%     2007.000000    173.000000          4.000000         2.000000
# 50%     2015.000000    240.000000          6.000000         4.000000
# 75%     2016.000000    304.000000          6.000000         4.000000
# max     2017.000000   1001.000000         16.000000         4.000000
#
#         highway MPG      city mpg    Popularity          MSRP
# count  11111.000000  11111.000000  11111.000000  1.111100e+04
# mean      26.630096     19.747187   1560.212222  4.214917e+04
# std        9.004138      9.208227   1445.992129  6.163034e+04
# min       12.000000      7.000000      2.000000  2.000000e+03
# ...

# %%
print(cars.shape)
# Out:
# (11111, 13)

# %%
cars['MSRP'].unique()
# Out:
# array([46135, 40650, 36350, ..., 46120, 50620, 50920], dtype=int64)

# %%
find = np.where(cars['MSRP'] == 36350)

find
# Out:
# (array([   2, 3348], dtype=int64),)

# %%
fd1 = np.where(cars['Popularity'] == 2 )

fd1
# Out:
# (array([1954, 1955], dtype=int64),)

# %%
s_t = np.sort(cars['MSRP'])

print(s_t)
# Out:
# [   2000    2000    2000 ... 1500000 1705769 2065902]

# %%
s_t1 = cars.sort_values(by=['Year'])

s_t1
# Out:
#             Make               Model  Year                Engine Fuel Type  \
# 9415  Mitsubishi               Sigma  1990                regular unleaded
# 6514        Ford  LTD Crown Victoria  1990                regular unleaded
# 6515        Ford  LTD Crown Victoria  1990                regular unleaded
# 6516        Ford  LTD Crown Victoria  1990                regular unleaded
# 6517        Ford  LTD Crown Victoria  1990                regular unleaded
# ...          ...                 ...   ...                             ...
# 6490       Lexus              LS 460  2017     premium unleaded (required)
# 6491       Lexus              LS 460  2017     premium unleaded (required)
# 6492       Lexus              LS 460  2017     premium unleaded (required)
# 6344  Mitsubishi              Lancer  2017                regular unleaded
# 7391  Mitsubishi           Outlander  2017  premium unleaded (recommended)
#
# ...

# %%
s_t1.loc[:5,['Year','Model','MSRP','Market Category']]
# Out:
#       Year               Model   MSRP          Market Category
# 9415  1990               Sigma   2000                      NaN
# 6514  1990  LTD Crown Victoria   2000                      NaN
# 6515  1990  LTD Crown Victoria   2000                      NaN
# 6516  1990  LTD Crown Victoria   2000                      NaN
# 6517  1990  LTD Crown Victoria   2000                      NaN
# ...    ...                 ...    ...                      ...
# 3786  2012             Eclipse  19499                Hatchback
# 3739  2012      E-Series Wagon  34320                Flex Fuel
# 7     2012            1 Series  39300  Luxury,High-Performance
# 6     2012            1 Series  44100       Luxury,Performance
# 5     2012            1 Series  31200       Luxury,Performance
#
# [4811 rows x 4 columns]

# %%
var = cars.dropna(subset = ['Engine Fuel Type'],inplace = True)
var

# %%
cars.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        0
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3739
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
var1 = cars['Number of Doors'].fillna(4,inplace = True)
var1

# %%
x = cars['Engine Cylinders'].mode()

var2 = cars['Engine Cylinders'].fillna(x,inplace = True)

var2

# %%
y = cars['Engine HP'].mean()

var3 = cars['Engine HP'].fillna(y,inplace = True)

var3

# %%
var4 = cars.fillna(method = 'ffill',inplace = True)

var4

# %%
cars.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     0
# Engine HP            0
# Engine Cylinders     0
# Transmission Type    0
# Driven_Wheels        0
# Number of Doors      0
# Market Category      0
# Vehicle Size         0
# Vehicle Style        0
# highway MPG          0
# city mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
cars.notnull().sum()
# Out:
# Make                 11911
# Model                11911
# Year                 11911
# Engine Fuel Type     11911
# Engine HP            11911
# Engine Cylinders     11911
# Transmission Type    11911
# Driven_Wheels        11911
# Number of Doors      11911
# Market Category      11911
# Vehicle Size         11911
# Vehicle Style        11911
# highway MPG          11911
# city mpg             11911
# Popularity           11911
# MSRP                 11911
# dtype: int64

# %%
cars.notnull().sum().sum()
# Out:
# 154843

# %%
cars
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
#        Engine Cylinders  Number of Doors  \
# ...
